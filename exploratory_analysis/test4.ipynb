# %% [markdown]
# **GOAL:**
# Combine the results from test3 and test2

# %%
from fama_data.FamaData import FamaData

from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
ff_df = pd.read_csv('exported/alt_ff_factors.csv')
if_df = pd.read_csv('exported/lasso_industry_factors.csv')

# %%
df = pd.concat([ff_df.drop('caldt', axis = 1), if_df.drop('caldt', axis = 1)], axis=1)
df.describe()
# Out:
#              exmt  share_issue_delta  shortterm_rev_delta  longterm_rev_delta
# count  711.000000         711.000000           711.000000          711.000000  \
# mean     0.005433          -0.428439            -0.330380           -0.321969
# std      0.044894           3.225668             5.529345            5.322832
# min     -0.232400         -12.380000           -37.920000          -33.380000
# 25%     -0.019700          -2.395000            -2.695000           -3.075000
# 50%      0.009100          -0.280000            -0.250000           -0.040000
# 75%      0.034000           1.540000             2.485000            2.680000
# max      0.161000          10.550000            25.390000           21.090000
#
#        innov_delta  growth_delta  durable_delta  service_minus_goods
# count   711.000000    711.000000     711.000000           711.000000  \
# mean      0.011772      0.160225       0.044543            -4.241210
# std       5.171849      3.418934       4.277288            27.565854
# min     -26.100000    -14.485000     -13.520000          -135.230000
# 25%      -2.785000     -1.800000      -2.255000           -14.585000
# 50%      -0.020000      0.135000      -0.220000            -0.680000
# 75%       2.870000      2.137500       1.975000            10.810000
# max      24.370000     15.285000      33.860000            88.900000
#
#        needs_minus_wants  accrual_delta  ...  SodaMinusTxtls  HshldMinusClths
# count         711.000000     711.000000  ...    7.110000e+02       711.000000  \
# mean           -6.706090      -0.327257  ...   -2.498392e-17         0.000000
# std            31.480629       2.810405  ...    1.000704e+00         1.000704
# min          -174.720000     -13.730000  ...   -4.439050e+00        -7.669491
# 25%           -12.400000      -1.865000  ...   -6.040516e-01        -0.554086
# 50%            -0.570000      -0.280000  ...    5.897122e-03         0.041536
# 75%             9.715000       1.245000  ...    5.861452e-01         0.553597
# max            75.750000      10.900000  ...    5.086871e+00         2.917625
#
#        HshldMinusTxtls  HshldMinusAero  HshldMinusChips  HshldMinusBoxes
# count     7.110000e+02    7.110000e+02     7.110000e+02     7.110000e+02  \
# mean      4.996784e-18   -6.245980e-18     1.499035e-17    -8.744373e-18
# std       1.000704e+00    1.000704e+00     1.000704e+00     1.000704e+00
# min      -8.151329e+00   -4.845767e+00    -6.412996e+00    -6.185943e+00
# 25%      -4.980836e-01   -5.721134e-01    -5.439408e-01    -5.916958e-01
# 50%      -9.078950e-04    1.646257e-02    -9.634904e-03    -6.008159e-03
# 75%       4.669263e-01    6.059640e-01     5.853310e-01     5.715450e-01
# max       4.719816e+00    5.380278e+00     5.220414e+00     4.235579e+00
#
#        HshldMinusBanks  MedEqMinusChips  DrugsMinusHardw  DrugsMinusBanks
# count     7.110000e+02     7.110000e+02     7.110000e+02     7.110000e+02
# mean     -6.245980e-18     9.993569e-18    -4.996784e-18     1.249196e-18
# std       1.000704e+00     1.000704e+00     1.000704e+00     1.000704e+00
# min      -6.190361e+00    -3.877625e+00    -4.229608e+00    -4.735851e+00
# 25%      -5.760044e-01    -5.675330e-01    -5.951459e-01    -5.866070e-01
# 50%       5.739336e-03     1.063779e-02     3.456753e-02     4.770939e-02
# 75%       5.853677e-01     6.274678e-01     5.651519e-01     5.976442e-01
# max       3.483509e+00     5.539772e+00     5.273783e+00     4.683844e+00
#
# [8 rows x 27 columns]

# %%
plt.rcParams["figure.figsize"] = (12, 8)
sns.heatmap(df.corr(), annot = False)
plt.show()

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns

vif_data["VIF"] = [variance_inflation_factor(df.values, i)
                          for i in range(len(df.columns))]
vif_data
# Out:
#                  feature       VIF
# 0                   exmt  2.249227
# 1      share_issue_delta  1.812056
# 2    shortterm_rev_delta  1.238286
# 3     longterm_rev_delta  1.706874
# 4            innov_delta  7.303307
# 5           growth_delta  4.956361
# 6          durable_delta  1.258350
# 7    service_minus_goods  1.367331
# 8      needs_minus_wants  1.358898
# 9          accrual_delta  1.127160
# 10  cashflow_price_delta  5.572589
# 11     market_beta_delta  5.832603
# 12  dividend_yield_delta  2.558093
# 13  earnings_price_delta  5.623678
# 14        variance_delta  4.421890
# 15       AgricMinusSteel  2.918210
# 16       AgricMinusChips  4.873749
# 17        SodaMinusTxtls  2.620152
# 18       HshldMinusClths  2.157301
# 19       HshldMinusTxtls  3.697427
# 20        HshldMinusAero  1.786840
# 21       HshldMinusChips  9.202218
# 22       HshldMinusBoxes  1.649093
# 23       HshldMinusBanks  7.808431
# 24       MedEqMinusChips  4.238010
# 25       DrugsMinusHardw  4.907671
# 26       DrugsMinusBanks  8.367925

# %%
# HshldMinusChips has a high VIF, so we drop it
df = df.drop('HshldMinusChips', axis = 1)
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns

vif_data["VIF"] = [variance_inflation_factor(df.values, i)
                          for i in range(len(df.columns))]
vif_data
# Out:
#                  feature       VIF
# 0                   exmt  2.245822
# 1      share_issue_delta  1.804555
# 2    shortterm_rev_delta  1.222605
# 3     longterm_rev_delta  1.701902
# 4            innov_delta  6.976129
# 5           growth_delta  4.749350
# 6          durable_delta  1.258340
# 7    service_minus_goods  1.366703
# 8      needs_minus_wants  1.349742
# 9          accrual_delta  1.127147
# 10  cashflow_price_delta  5.549389
# 11     market_beta_delta  5.619119
# 12  dividend_yield_delta  2.536359
# 13  earnings_price_delta  5.588851
# 14        variance_delta  4.409128
# 15       AgricMinusSteel  2.612701
# 16       AgricMinusChips  4.089449
# 17        SodaMinusTxtls  2.570750
# 18       HshldMinusClths  2.129482
# 19       HshldMinusTxtls  3.635318
# 20        HshldMinusAero  1.757304
# 21       HshldMinusBoxes  1.591024
# 22       HshldMinusBanks  5.930244
# 23       MedEqMinusChips  2.715595
# 24       DrugsMinusHardw  4.725767
# 25       DrugsMinusBanks  6.632764

# %%
# Seems like we're good to go

# %%
# Our first testing portfolios
# Equal-weighted momentum portfolios
url = 'http://diether.org/prephd/10-port_mom_ew.csv'
port = pd.read_csv(url,parse_dates=['caldt'])
port = port.query('caldt >= "1963-07-31" and caldt <= "2023-02-28"')
port = port.drop('caldt', axis = 1)
port.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 711 entries, 438 to 1148
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   p0      711 non-null    float64
#  1   p1      711 non-null    float64
#  2   p2      711 non-null    float64
#  3   p3      711 non-null    float64
#  4   p4      711 non-null    float64
# dtypes: float64(5)
# memory usage: 33.3 KB

# %%
regressors = df.columns
df = pd.concat([port.reset_index(drop = True), df.reset_index(drop = True)], axis=1)

# %%
ols('p4 - p0 ~ 1 + ' + ' + '.join(regressors), data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p4   R-squared:                       0.828
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     126.7
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):          2.13e-241
# Time:                        18:31:28   Log-Likelihood:                -1680.2
# No. Observations:                 711   AIC:                             3414.
# Df Residuals:                     684   BIC:                             3538.
# Df Model:                          26
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.1978      0.108     11.044      0.000       0.985       1.411
# exmt                    93.8040      3.306     28.378      0.000      87.314     100.294
# share_issue_delta        0.1328      0.041      3.252      0.001       0.053       0.213
# shortterm_rev_delta      0.0454      0.020      2.311      0.021       0.007       0.084
# longterm_rev_delta      -0.1428      0.024     -5.929      0.000      -0.190      -0.096
# innov_delta              0.0141      0.050      0.280      0.780      -0.085       0.113
# growth_delta            -0.0827      0.063     -1.318      0.188      -0.206       0.041
# durable_delta           -0.1185      0.026     -4.588      0.000      -0.169      -0.068
# service_minus_goods      0.0116      0.004      2.764      0.006       0.003       0.020
# needs_minus_wants       -0.0052      0.004     -1.435      0.152      -0.012       0.002
# accrual_delta           -0.0633      0.037     -1.702      0.089      -0.136       0.010
# cashflow_price_delta    -0.0205      0.053     -0.389      0.697      -0.124       0.083
# market_beta_delta        0.0260      0.035      0.741      0.459      -0.043       0.095
# dividend_yield_delta    -0.1234      0.030     -4.169      0.000      -0.182      -0.065
# earnings_price_delta     0.1444      0.054      2.686      0.007       0.039       0.250
# variance_delta           0.2075      0.026      7.934      0.000       0.156       0.259
# AgricMinusSteel          0.3820      0.159      2.403      0.017       0.070       0.694
# AgricMinusChips          0.0692      0.199      0.348      0.728      -0.321       0.459
# SodaMinusTxtls           0.1396      0.158      0.886      0.376      -0.170       0.449
# HshldMinusClths          0.0326      0.143      0.227      0.820      -0.249       0.314
# HshldMinusTxtls         -0.6453      0.187     -3.443      0.001      -1.013      -0.277
# HshldMinusAero           0.0559      0.130      0.429      0.668      -0.200       0.312
# HshldMinusBoxes          0.0990      0.124      0.799      0.425      -0.144       0.342
# HshldMinusBanks          0.2646      0.240      1.104      0.270      -0.206       0.735
# MedEqMinusChips          0.2917      0.162      1.801      0.072      -0.026       0.610
# DrugsMinusHardw         -0.0407      0.214     -0.191      0.849      -0.460       0.379
# DrugsMinusBanks          0.4938      0.253      1.949      0.052      -0.004       0.991
# ==============================================================================
# Omnibus:                       75.913   Durbin-Watson:                   1.682
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              515.812
# Skew:                           0.123   Prob(JB):                    9.84e-113
# Kurtosis:                       7.165   Cond. No.                     1.11e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns

vif_data["VIF"] = [variance_inflation_factor(df.values, i)
                          for i in range(len(df.columns))]
vif_data
# Out:
#                  feature        VIF
# 0                     p0  23.052557
# 1                     p1  58.014588
# 2                     p2  76.509095
# 3                     p3  57.744148
# 4                     p4  21.689709
# 5                   exmt  10.298445
# 6      share_issue_delta   1.849885
# 7    shortterm_rev_delta   1.286544
# 8     longterm_rev_delta   1.814289
# 9            innov_delta   7.284260
# 10          growth_delta   4.790884
# 11         durable_delta   1.305151
# 12   service_minus_goods   1.373836
# 13     needs_minus_wants   1.398142
# 14         accrual_delta   1.173348
# 15  cashflow_price_delta   5.621411
# 16     market_beta_delta   5.809222
# 17  dividend_yield_delta   2.698512
# 18  earnings_price_delta   5.757558
# 19        variance_delta   7.096946
# 20       AgricMinusSteel   2.675218
# 21       AgricMinusChips   4.097126
# 22        SodaMinusTxtls   2.597900
# 23       HshldMinusClths   2.181059
# 24       HshldMinusTxtls   3.846964
# 25        HshldMinusAero   1.815959
# 26       HshldMinusBoxes   1.594904
# 27       HshldMinusBanks   6.103974
# 28       MedEqMinusChips   2.764319
# 29       DrugsMinusHardw   4.769616
# 30       DrugsMinusBanks   6.915791

# %% [markdown]
# Are we getting nowhere?

# %% [markdown]
# Let's break: add the Fama French Factors

# %%
fd = FamaData('data/', end_date = '2022-09-30')
SMB_proxy = fd.get_size_data()['Hi 10'] - fd.get_size_data()['Lo 10']
HML_proxy = fd.get_book_to_market_data()['Hi 10'] - fd.get_book_to_market_data()['Lo 10']

# Fama-French 5-factor model components
RMW_proxy = fd.get_operating_profitability_data()['Hi 10'] - fd.get_operating_profitability_data()['Lo 10']
CMA_proxy = fd.get_investment_data()['Hi 10'] - fd.get_investment_data()['Lo 10']

# And momentum
MOM_proxy = fd.get_momentum_data()['Hi PRIOR'] - fd.get_momentum_data()['Lo PRIOR']

SMB_proxy.name = 'SMB'
HML_proxy.name = 'HML'
RMW_proxy.name = 'RMW'
CMA_proxy.name = 'CMA'
MOM_proxy.name = 'MOM'

# %%
fama_factors = pd.concat([SMB_proxy.reset_index(drop=True), HML_proxy.reset_index(drop=True), RMW_proxy.reset_index(drop=True), 
                        CMA_proxy.reset_index(drop=True), MOM_proxy.reset_index(drop=True)], axis = 1)

df = pd.concat([df.reset_index(drop=True), fama_factors.reset_index(drop=True)], axis = 1)
df.head(3)
# Out:
#          p0        p1        p2        p3        p4    exmt
# 0 -1.643322 -1.284810 -0.512732 -0.979859 -0.385561 -0.0039  \
# 1  2.761947  3.405911  4.273330  4.401903  6.501132  0.0507
# 2 -2.617577 -0.725381 -1.154537 -1.158321 -1.688062 -0.0157
#
#    share_issue_delta  shortterm_rev_delta  longterm_rev_delta  innov_delta
# 0               2.09                -0.16               -1.34        -0.20  \
# 1               1.55                -0.64                0.52         0.25
# 2              -1.86                -0.89                2.00         1.82
#
#    ...  HshldMinusBoxes  HshldMinusBanks  MedEqMinusChips  DrugsMinusHardw
# 0  ...        -0.115244         0.310362        -0.056372         0.146697  \
# 1  ...         0.163655         0.445749         0.254621         0.827600
# 2  ...         0.161331         0.375940         0.036411        -0.987600
#
#    DrugsMinusBanks   SMB   HML   RMW   CMA   MOM
# 0         0.420152  0.55 -2.66  2.42  3.07  2.98
# 1         1.035070  2.67  1.67  0.54  2.32  3.23
# 2        -0.225803 -0.73 -1.77  2.05 -1.02  1.16
#
# [3 rows x 36 columns]

# %%
regressors = regressors.append(pd.Index(['SMB', 'HML', 'RMW', 'CMA', 'MOM']))

# %%
ols('p4 - p0 ~ 1 + ' + ' + '.join(regressors), data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p4   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     489.8
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:39:42   Log-Likelihood:                -1185.9
# No. Observations:                 711   AIC:                             2436.
# Df Residuals:                     679   BIC:                             2582.
# Df Model:                          31
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.6299      0.056     11.250      0.000       0.520       0.740
# exmt                   106.3191      1.720     61.800      0.000     102.941     109.697
# share_issue_delta       -0.0284      0.022     -1.277      0.202      -0.072       0.015
# shortterm_rev_delta     -0.0517      0.010     -4.988      0.000      -0.072      -0.031
# longterm_rev_delta      -0.0227      0.014     -1.642      0.101      -0.050       0.004
# innov_delta              0.0074      0.026      0.285      0.776      -0.044       0.058
# growth_delta          8.393e-05      0.032      0.003      0.998      -0.062       0.062
# durable_delta           -0.0204      0.013     -1.552      0.121      -0.046       0.005
# service_minus_goods      0.0021      0.002      0.981      0.327      -0.002       0.006
# needs_minus_wants        0.0002      0.002      0.086      0.932      -0.003       0.004
# accrual_delta            0.0122      0.019      0.627      0.531      -0.026       0.050
# cashflow_price_delta     0.0131      0.027      0.488      0.626      -0.040       0.066
# market_beta_delta       -0.0173      0.018     -0.971      0.332      -0.052       0.018
# dividend_yield_delta    -0.0144      0.016     -0.914      0.361      -0.045       0.017
# earnings_price_delta    -0.0067      0.028     -0.243      0.808      -0.061       0.048
# variance_delta           0.0801      0.015      5.277      0.000       0.050       0.110
# AgricMinusSteel         -0.0951      0.082     -1.162      0.246      -0.256       0.066
# AgricMinusChips          0.1790      0.101      1.768      0.078      -0.020       0.378
# SodaMinusTxtls          -0.0352      0.079     -0.445      0.657      -0.190       0.120
# HshldMinusClths          0.1037      0.073      1.429      0.154      -0.039       0.246
# HshldMinusTxtls         -0.0849      0.097     -0.879      0.380      -0.274       0.105
# HshldMinusAero           0.0761      0.067      1.143      0.253      -0.055       0.207
# HshldMinusBoxes         -0.0584      0.062     -0.935      0.350      -0.181       0.064
# HshldMinusBanks         -0.1255      0.121     -1.034      0.302      -0.364       0.113
# MedEqMinusChips          0.0839      0.082      1.022      0.307      -0.077       0.245
# DrugsMinusHardw         -0.0668      0.109     -0.615      0.539      -0.280       0.146
# DrugsMinusBanks          0.1734      0.129      1.341      0.180      -0.080       0.427
# SMB                     -0.4935      0.018    -27.396      0.000      -0.529      -0.458
# HML                      0.0125      0.021      0.598      0.550      -0.029       0.054
# RMW                     -0.0416      0.019     -2.178      0.030      -0.079      -0.004
# CMA                      0.0331      0.021      1.603      0.109      -0.007       0.074
# MOM                      0.2584      0.009     28.647      0.000       0.241       0.276
# ==============================================================================
# Omnibus:                       17.785   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.634
# Skew:                           0.232   Prob(JB):                     2.71e-06
# Kurtosis:                       3.806   Cond. No.                     1.15e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Just the CAPM regression
ols('p4 ~ 1 + exmt', data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p4   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     1705.
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):          8.95e-191
# Time:                        18:35:33   Log-Likelihood:                -1870.6
# No. Observations:                 711   AIC:                             3745.
# Df Residuals:                     709   BIC:                             3754.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9648      0.127      7.590      0.000       0.715       1.214
# exmt         116.1405      2.813     41.287      0.000     110.618     121.663
# ==============================================================================
# Omnibus:                      184.228   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1599.330
# Skew:                           0.901   Prob(JB):                         0.00
# Kurtosis:                      10.123   Cond. No.                         22.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Here we compute the R2 across each portfolio
portfolios = ['p0', 'p1', 'p2', 'p3', 'p4']

for portfolio in portfolios:
    print(portfolio, '\t', ols(portfolio + ' ~ 1 + ' + ' + '.join(regressors), data=df).fit().rsquared)
# Out:
# p0 	 0.9398594807530057
# p1 	 0.9419286712447897
# p2 	 0.9568414004480682
# p3 	 0.9613022170965534
# p4 	 0.9571917792639295

# %%
# Okay, fine, but we're worried about too many regressors
# Let's try LASSO

X = df.copy()[regressors]
mapper = DataFrameMapper([(X.columns, StandardScaler())]).fit(X)
scaled_vals = mapper.transform(X)
X = pd.DataFrame(scaled_vals, columns=X.columns)
X.describe()
# Out:
#                exmt  share_issue_delta  shortterm_rev_delta
# count  7.110000e+02       7.110000e+02         7.110000e+02  \
# mean  -1.499035e-17      -9.993569e-18        -1.499035e-17
# std    1.000704e+00       1.000704e+00         1.000704e+00
# min   -5.301386e+00      -3.707751e+00        -6.802990e+00
# 25%   -5.602305e-01      -6.100893e-01        -4.279503e-01
# 50%    8.173124e-02       4.605041e-02         1.454717e-02
# 75%    6.367607e-01       6.106718e-01         5.095290e-01
# max    3.467634e+00       3.405858e+00         4.654889e+00
#
#        longterm_rev_delta   innov_delta  growth_delta  durable_delta
# count        7.110000e+02  7.110000e+02  7.110000e+02   7.110000e+02  \
# mean         4.996784e-18  9.993569e-18 -3.747588e-17   2.748231e-17
# std          1.000704e+00  1.000704e+00  1.000704e+00   1.000704e+00
# min         -6.214981e+00 -5.052382e+00 -4.286580e+00  -3.173528e+00
# 25%         -5.175758e-01 -5.411490e-01 -5.737475e-01  -5.379956e-01
# 50%          5.301079e-02 -6.147612e-03 -7.383235e-03  -6.189182e-02
# 75%          5.643767e-01  5.530401e-01  5.787379e-01   4.516451e-01
# max          4.025497e+00  4.713087e+00  4.426942e+00   7.911383e+00
#
#        service_minus_goods  needs_minus_wants  accrual_delta  ...
# count         7.110000e+02       7.110000e+02   7.110000e+02  ...  \
# mean          1.998714e-17       5.996141e-17   2.248553e-17  ...
# std           1.000704e+00       1.000704e+00   1.000704e+00  ...
# min          -4.755195e+00      -5.340814e+00  -4.772330e+00  ...
# 25%          -3.755034e-01      -1.809976e-01  -5.475458e-01  ...
# 50%           1.292801e-01       1.950536e-01   1.682699e-02  ...
# 75%           5.463936e-01       5.219924e-01   5.598355e-01  ...
# max           3.381240e+00       2.621108e+00   3.997702e+00  ...
#
#        HshldMinusBoxes  HshldMinusBanks  MedEqMinusChips  DrugsMinusHardw
# count     7.110000e+02     7.110000e+02     7.110000e+02     7.110000e+02  \
# mean     -7.495177e-18    -6.245980e-18     9.993569e-18    -1.998714e-17
# std       1.000704e+00     1.000704e+00     1.000704e+00     1.000704e+00
# min      -6.185943e+00    -6.190361e+00    -3.877625e+00    -4.229608e+00
# 25%      -5.916958e-01    -5.760044e-01    -5.675330e-01    -5.951459e-01
# 50%      -6.008159e-03     5.739336e-03     1.063779e-02     3.456753e-02
# 75%       5.715450e-01     5.853677e-01     6.274678e-01     5.651519e-01
# max       4.235579e+00     3.483509e+00     5.539772e+00     5.273783e+00
#
#        DrugsMinusBanks           SMB           HML           RMW
# count     7.110000e+02  7.110000e+02  7.110000e+02  7.110000e+02  \
# mean      1.249196e-18  4.996784e-18 -2.248553e-17 -2.498392e-18
# std       1.000704e+00  1.000704e+00  1.000704e+00  1.000704e+00
# min      -4.735851e+00 -6.639129e+00 -5.600999e+00 -4.925306e+00
# 25%      -5.866070e-01 -5.150919e-01 -5.883883e-01 -5.619994e-01
# 50%       4.770939e-02  4.334677e-02 -6.276398e-02  2.386962e-02
# 75%       5.976442e-01  6.122236e-01  5.789745e-01  5.353238e-01
# max       4.683844e+00  4.423176e+00  4.067585e+00  4.982495e+00
#
#                 CMA           MOM
# count  7.110000e+02  7.110000e+02
# mean  -1.249196e-18 -2.998071e-17
# std    1.000704e+00  1.000704e+00
# min   -4.650430e+00 -6.509633e+00
# 25%   -5.156141e-01 -3.783122e-01
# 50%    1.418697e-02  6.494963e-02
# 75%    6.416609e-01  5.313565e-01
# max    3.293626e+00  3.171991e+00
#
# [8 rows x 31 columns]

# %% [markdown]
# Let's train LASSO on each of our 4 portfolios

# %%
portfolios = ['p0', 'p1', 'p2', 'p3', 'p4']

for portfolio in portfolios:
    print('TESTING PORTFOLIO: ', portfolio)
    y = df[portfolio]

    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

    alpha_grid = {'alpha': np.logspace(-2, -1, 200)}
    lasso_grid = GridSearchCV(Lasso(),alpha_grid,cv=5,return_train_score=True, n_jobs=-1)
    best_lasso=lasso_grid.fit(X_train,y_train)
    print("Best alpha: ",best_lasso.best_estimator_.get_params()['alpha'])
    print("Train set score: {:.2f}".format(lasso_grid.score(X_train,y_train)))

    # Now score the test set
    print("Test set score: {:.2f}".format(lasso_grid.score(X_test,y_test)))

    # And the MSE:
    y_pred = lasso_grid.predict(X_test)
    print("MSE: {:.2f}".format(mean_squared_error(y_test, y_pred)))

    print(f'Using GridSearchCV, we retain the following Xs out of {len(X.columns)} Xs')
    print(*(x for x in list(zip(X.columns.tolist(), np.round(best_lasso.best_estimator_.coef_, 3)))))

    mask = [True if abs(x) > 0.001 else False for x in list(best_lasso.best_estimator_.coef_)]
    kept = pd.Series(X.columns)[mask]
    print('RETAINED Xs: \n', kept)

    print(ols(portfolio + ' ~ 1 + ' + ' + '.join(kept), data=df).fit().summary())

    print('====================================================================================================', end='\n\n\n\n\n\n\n\n\n')
# Out:
# TESTING PORTFOLIO:  p0
# Best alpha:  0.07149428986597577
# Train set score: 0.94
# Test set score: 0.94
# MSE: 4.30
# Using GridSearchCV, we retain the following Xs out of 31 Xs
# ('exmt', 4.299) ('share_issue_delta', 0.051) ('shortterm_rev_delta', 0.0) ('longterm_rev_delta', 0.0) ('innov_delta', 0.02) ('growth_delta', -0.0) ('durable_delta', 0.0) ('service_minus_goods', 0.0) ('needs_minus_wants', -0.02) ('accrual_delta', 0.03) ('cashflow_price_delta', 0.185) ('market_beta_delta', 0.36) ('dividend_yield_delta', -0.0) ('earnings_price_delta', -0.0) ('variance_delta', 0.631) ('AgricMinusSteel', -0.0) ('AgricMinusChips', -0.105) ('SodaMinusTxtls', -0.155) ('HshldMinusClths', -0.181) ('HshldMinusTxtls', -0.0) ('HshldMinusAero', -0.015) ('HshldMinusBoxes', -0.104) ('HshldMinusBanks', 0.0) ('MedEqMinusChips', -0.0) ('DrugsMinusHardw', -0.061) ('DrugsMinusBanks', -0.0) ('SMB', -1.755) ('HML', 0.0) ('RMW', -0.394) ('CMA', 0.399) ('MOM', -2.361)
# RETAINED Xs:
#  0                     exmt
# 1        share_issue_delta
# 4              innov_delta
# 8        needs_minus_wants
# 9            accrual_delta
# 10    cashflow_price_delta
# 11       market_beta_delta
# 14          variance_delta
# 16         AgricMinusChips
# 17          SodaMinusTxtls
# 18         HshldMinusClths
# 20          HshldMinusAero
# 21         HshldMinusBoxes
# 24         DrugsMinusHardw
# 26                     SMB
# 28                     RMW
# 29                     CMA
# 30                     MOM
# dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p0   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     585.9
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:58:10   Log-Likelihood:                -1462.7
# No. Observations:                 711   AIC:                             2963.
# Df Residuals:                     692   BIC:                             3050.
# Df Model:                          18
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.1206      0.079      1.522      0.129      -0.035       0.276
# exmt                    98.6367      2.377     41.490      0.000      93.969     103.304
# share_issue_delta        0.0308      0.032      0.972      0.331      -0.031       0.093
# innov_delta             -0.0024      0.031     -0.077      0.939      -0.064       0.059
# needs_minus_wants       -0.0026      0.003     -1.024      0.306      -0.008       0.002
# accrual_delta            0.0196      0.028      0.704      0.482      -0.035       0.074
# cashflow_price_delta     0.0596      0.021      2.804      0.005       0.018       0.101
# market_beta_delta        0.0257      0.024      1.063      0.288      -0.022       0.073
# variance_delta           0.0892      0.021      4.199      0.000       0.047       0.131
# AgricMinusChips         -0.0604      0.091     -0.662      0.508      -0.239       0.119
# SodaMinusTxtls          -0.0880      0.085     -1.040      0.299      -0.254       0.078
# HshldMinusClths         -0.3238      0.095     -3.411      0.001      -0.510      -0.137
# HshldMinusAero           0.0645      0.090      0.716      0.475      -0.113       0.242
# HshldMinusBoxes         -0.0926      0.083     -1.114      0.266      -0.256       0.071
# DrugsMinusHardw          0.0159      0.119      0.134      0.893      -0.217       0.249
# SMB                     -0.3704      0.024    -15.458      0.000      -0.417      -0.323
# RMW                     -0.0840      0.026     -3.199      0.001      -0.135      -0.032
# CMA                      0.1401      0.027      5.197      0.000       0.087       0.193
# MOM                     -0.3715      0.011    -33.181      0.000      -0.394      -0.350
# ==============================================================================
# Omnibus:                       76.904   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              554.690
# Skew:                          -0.061   Prob(JB):                    3.55e-121
# Kurtosis:                       7.325   Cond. No.                     1.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
#
#
#
#
#
#
# TESTING PORTFOLIO:  p1
# Best alpha:  0.053535666774107246
# Train set score: 0.94
# Test set score: 0.92
# MSE: 2.88
# Using GridSearchCV, we retain the following Xs out of 31 Xs
# ('exmt', 4.189) ('share_issue_delta', 0.02) ('shortterm_rev_delta', -0.048) ('longterm_rev_delta', -0.041) ('innov_delta', -0.0) ('growth_delta', -0.082) ('durable_delta', 0.0) ('service_minus_goods', 0.0) ('needs_minus_wants', -0.039) ('accrual_delta', 0.12) ('cashflow_price_delta', 0.135) ('market_beta_delta', 0.029) ('dividend_yield_delta', -0.0) ('earnings_price_delta', 0.054) ('variance_delta', -0.0) ('AgricMinusSteel', -0.0) ('AgricMinusChips', -0.053) ('SodaMinusTxtls', -0.206) ('HshldMinusClths', -0.265) ('HshldMinusTxtls', -0.156) ('HshldMinusAero', -0.091) ('HshldMinusBoxes', -0.008) ('HshldMinusBanks', 0.042) ('MedEqMinusChips', -0.0) ('DrugsMinusHardw', -0.0) ('DrugsMinusBanks', -0.178) ('SMB', -1.434) ('HML', 0.061) ('RMW', -0.0) ('CMA', 0.181) ('MOM', -1.024)
# RETAINED Xs:
#  0                     exmt
# 1        share_issue_delta
# 2      shortterm_rev_delta
# 3       longterm_rev_delta
# 5             growth_delta
# 8        needs_minus_wants
# 9            accrual_delta
# 10    cashflow_price_delta
# 11       market_beta_delta
# 13    earnings_price_delta
# 16         AgricMinusChips
# 17          SodaMinusTxtls
# 18         HshldMinusClths
# 19         HshldMinusTxtls
# 20          HshldMinusAero
# 21         HshldMinusBoxes
# 22         HshldMinusBanks
# 25         DrugsMinusBanks
# 26                     SMB
# 27                     HML
# 29                     CMA
# 30                     MOM
# dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p1   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     485.0
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:58:10   Log-Likelihood:                -1256.3
# No. Observations:                 711   AIC:                             2559.
# Df Residuals:                     688   BIC:                             2664.
# Df Model:                          22
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.4846      0.059      8.208      0.000       0.369       0.600
# exmt                    94.6745      1.792     52.831      0.000      91.156      98.193
# share_issue_delta        0.0255      0.023      1.092      0.275      -0.020       0.071
# shortterm_rev_delta     -0.0154      0.011     -1.354      0.176      -0.038       0.007
# longterm_rev_delta       0.0121      0.015      0.825      0.410      -0.017       0.041
# growth_delta            -0.0163      0.029     -0.571      0.568      -0.072       0.040
# needs_minus_wants       -0.0011      0.002     -0.550      0.582      -0.005       0.003
# accrual_delta            0.0302      0.021      1.472      0.142      -0.010       0.070
# cashflow_price_delta    -0.0258      0.028     -0.917      0.359      -0.081       0.029
# market_beta_delta       -0.0213      0.017     -1.261      0.208      -0.055       0.012
# earnings_price_delta     0.0753      0.028      2.682      0.007       0.020       0.130
# AgricMinusChips          0.0434      0.065      0.671      0.502      -0.084       0.170
# SodaMinusTxtls          -0.0574      0.083     -0.689      0.491      -0.221       0.106
# HshldMinusClths         -0.3866      0.077     -5.048      0.000      -0.537      -0.236
# HshldMinusTxtls         -0.3288      0.102     -3.222      0.001      -0.529      -0.128
# HshldMinusAero          -0.0666      0.070     -0.953      0.341      -0.204       0.071
# HshldMinusBoxes         -0.0271      0.065     -0.415      0.678      -0.155       0.101
# HshldMinusBanks          0.3657      0.108      3.371      0.001       0.153       0.579
# DrugsMinusBanks         -0.3435      0.108     -3.183      0.002      -0.555      -0.132
# SMB                     -0.3065      0.018    -17.382      0.000      -0.341      -0.272
# HML                      0.0281      0.022      1.277      0.202      -0.015       0.071
# CMA                      0.0684      0.022      3.059      0.002       0.024       0.112
# MOM                     -0.1818      0.009    -19.989      0.000      -0.200      -0.164
# ==============================================================================
# Omnibus:                       93.275   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              878.281
# Skew:                           0.122   Prob(JB):                    1.92e-191
# Kurtosis:                       8.439   Cond. No.                     1.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
#
#
#
#
#
#
# TESTING PORTFOLIO:  p2
# Best alpha:  0.01135733358343105
# Train set score: 0.96
# Test set score: 0.95
# MSE: 1.37
# Using GridSearchCV, we retain the following Xs out of 31 Xs
# ('exmt', 4.208) ('share_issue_delta', -0.0) ('shortterm_rev_delta', -0.111) ('longterm_rev_delta', -0.064) ('innov_delta', -0.241) ('growth_delta', -0.0) ('durable_delta', -0.033) ('service_minus_goods', 0.025) ('needs_minus_wants', -0.074) ('accrual_delta', 0.101) ('cashflow_price_delta', 0.096) ('market_beta_delta', 0.087) ('dividend_yield_delta', -0.01) ('earnings_price_delta', 0.038) ('variance_delta', -0.516) ('AgricMinusSteel', 0.096) ('AgricMinusChips', -0.022) ('SodaMinusTxtls', -0.196) ('HshldMinusClths', -0.201) ('HshldMinusTxtls', -0.145) ('HshldMinusAero', -0.137) ('HshldMinusBoxes', -0.008) ('HshldMinusBanks', 0.152) ('MedEqMinusChips', 0.087) ('DrugsMinusHardw', 0.0) ('DrugsMinusBanks', -0.227) ('SMB', -1.545) ('HML', 0.189) ('RMW', 0.086) ('CMA', 0.11) ('MOM', -0.19)
# RETAINED Xs:
#  0                     exmt
# 2      shortterm_rev_delta
# 3       longterm_rev_delta
# 4              innov_delta
# 6            durable_delta
# 7      service_minus_goods
# 8        needs_minus_wants
# 9            accrual_delta
# 10    cashflow_price_delta
# 11       market_beta_delta
# 12    dividend_yield_delta
# 13    earnings_price_delta
# 14          variance_delta
# 15         AgricMinusSteel
# 16         AgricMinusChips
# 17          SodaMinusTxtls
# 18         HshldMinusClths
# 19         HshldMinusTxtls
# 20          HshldMinusAero
# 21         HshldMinusBoxes
# 22         HshldMinusBanks
# 23         MedEqMinusChips
# 25         DrugsMinusBanks
# 26                     SMB
# 27                     HML
# 28                     RMW
# 29                     CMA
# 30                     MOM
# dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p2   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     533.9
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:58:11   Log-Likelihood:                -1023.3
# No. Observations:                 711   AIC:                             2105.
# Df Residuals:                     682   BIC:                             2237.
# Df Model:                          28
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.4779      0.044     10.843      0.000       0.391       0.564
# exmt                    93.4998      1.364     68.535      0.000      90.821      96.178
# shortterm_rev_delta     -0.0251      0.008     -3.057      0.002      -0.041      -0.009
# longterm_rev_delta       0.0081      0.011      0.744      0.457      -0.013       0.030
# innov_delta             -0.0655      0.014     -4.585      0.000      -0.094      -0.037
# durable_delta           -0.0110      0.010     -1.064      0.288      -0.031       0.009
# service_minus_goods      0.0028      0.002      1.655      0.098      -0.001       0.006
# needs_minus_wants       -0.0025      0.001     -1.737      0.083      -0.005       0.000
# accrual_delta            0.0149      0.015      0.972      0.331      -0.015       0.045
# cashflow_price_delta    -0.0027      0.021     -0.129      0.897      -0.044       0.038
# market_beta_delta        0.0269      0.014      1.948      0.052      -0.000       0.054
# dividend_yield_delta    -0.0138      0.012     -1.139      0.255      -0.038       0.010
# earnings_price_delta     0.0254      0.022      1.163      0.245      -0.017       0.068
# variance_delta          -0.0775      0.012     -6.507      0.000      -0.101      -0.054
# AgricMinusSteel          0.1589      0.061      2.593      0.010       0.039       0.279
# AgricMinusChips         -0.0873      0.075     -1.165      0.244      -0.234       0.060
# SodaMinusTxtls          -0.1667      0.061     -2.717      0.007      -0.287      -0.046
# HshldMinusClths         -0.2404      0.056     -4.288      0.000      -0.350      -0.130
# HshldMinusTxtls         -0.1994      0.076     -2.637      0.009      -0.348      -0.051
# HshldMinusAero          -0.1348      0.052     -2.605      0.009      -0.236      -0.033
# HshldMinusBoxes         -0.0144      0.049     -0.295      0.768      -0.110       0.081
# HshldMinusBanks          0.2914      0.076      3.818      0.000       0.142       0.441
# MedEqMinusChips          0.1870      0.063      2.992      0.003       0.064       0.310
# DrugsMinusBanks         -0.3013      0.071     -4.264      0.000      -0.440      -0.163
# SMB                     -0.3195      0.014    -22.765      0.000      -0.347      -0.292
# HML                      0.0648      0.017      3.899      0.000       0.032       0.097
# RMW                      0.0188      0.015      1.278      0.202      -0.010       0.048
# CMA                      0.0285      0.016      1.831      0.068      -0.002       0.059
# MOM                     -0.0504      0.007     -7.085      0.000      -0.064      -0.036
# ==============================================================================
# Omnibus:                       88.484   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              509.900
# Skew:                           0.371   Prob(JB):                    1.89e-111
# Kurtosis:                       7.082   Cond. No.                     1.15e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
#
#
#
#
#
#
# TESTING PORTFOLIO:  p3
# Best alpha:  0.018464249428955436
# Train set score: 0.96
# Test set score: 0.96
# MSE: 0.94
# Using GridSearchCV, we retain the following Xs out of 31 Xs
# ('exmt', 4.28) ('share_issue_delta', -0.0) ('shortterm_rev_delta', -0.123) ('longterm_rev_delta', -0.0) ('innov_delta', -0.288) ('growth_delta', -0.0) ('durable_delta', -0.06) ('service_minus_goods', 0.067) ('needs_minus_wants', -0.078) ('accrual_delta', -0.0) ('cashflow_price_delta', 0.099) ('market_beta_delta', 0.0) ('dividend_yield_delta', -0.133) ('earnings_price_delta', 0.0) ('variance_delta', -0.372) ('AgricMinusSteel', 0.074) ('AgricMinusChips', -0.0) ('SodaMinusTxtls', -0.106) ('HshldMinusClths', -0.023) ('HshldMinusTxtls', -0.124) ('HshldMinusAero', -0.083) ('HshldMinusBoxes', -0.001) ('HshldMinusBanks', 0.0) ('MedEqMinusChips', 0.063) ('DrugsMinusHardw', -0.0) ('DrugsMinusBanks', -0.073) ('SMB', -1.821) ('HML', 0.24) ('RMW', 0.115) ('CMA', 0.0) ('MOM', 0.462)
# RETAINED Xs:
#  0                     exmt
# 2      shortterm_rev_delta
# 4              innov_delta
# 6            durable_delta
# 7      service_minus_goods
# 8        needs_minus_wants
# 10    cashflow_price_delta
# 12    dividend_yield_delta
# 14          variance_delta
# 15         AgricMinusSteel
# 17          SodaMinusTxtls
# 18         HshldMinusClths
# 19         HshldMinusTxtls
# 20          HshldMinusAero
# 23         MedEqMinusChips
# 25         DrugsMinusBanks
# 26                     SMB
# 27                     HML
# 28                     RMW
# 30                     MOM
# dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p3   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     840.5
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:58:12   Log-Likelihood:                -975.96
# No. Observations:                 711   AIC:                             1994.
# Df Residuals:                     690   BIC:                             2090.
# Df Model:                          20
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.5061      0.040     12.576      0.000       0.427       0.585
# exmt                    95.8749      1.183     81.070      0.000      93.553      98.197
# shortterm_rev_delta     -0.0311      0.008     -4.094      0.000      -0.046      -0.016
# innov_delta             -0.0663      0.012     -5.377      0.000      -0.090      -0.042
# durable_delta           -0.0106      0.009     -1.124      0.261      -0.029       0.008
# service_minus_goods      0.0035      0.001      2.364      0.018       0.001       0.006
# needs_minus_wants       -0.0033      0.001     -2.590      0.010      -0.006      -0.001
# cashflow_price_delta     0.0166      0.013      1.271      0.204      -0.009       0.042
# dividend_yield_delta    -0.0426      0.010     -4.094      0.000      -0.063      -0.022
# variance_delta          -0.0616      0.010     -6.016      0.000      -0.082      -0.042
# AgricMinusSteel          0.0884      0.041      2.149      0.032       0.008       0.169
# SodaMinusTxtls          -0.1641      0.056     -2.936      0.003      -0.274      -0.054
# HshldMinusClths         -0.0685      0.050     -1.368      0.172      -0.167       0.030
# HshldMinusTxtls         -0.0781      0.067     -1.169      0.243      -0.209       0.053
# HshldMinusAero          -0.0817      0.045     -1.810      0.071      -0.170       0.007
# MedEqMinusChips          0.0714      0.049      1.461      0.144      -0.025       0.167
# DrugsMinusBanks         -0.0588      0.049     -1.199      0.231      -0.155       0.037
# SMB                     -0.3819      0.012    -32.068      0.000      -0.405      -0.358
# HML                      0.0612      0.014      4.494      0.000       0.034       0.088
# RMW                      0.0297      0.013      2.259      0.024       0.004       0.056
# MOM                      0.0608      0.006      9.485      0.000       0.048       0.073
# ==============================================================================
# Omnibus:                       10.501   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               13.883
# Skew:                          -0.156   Prob(JB):                     0.000967
# Kurtosis:                       3.610   Cond. No.                     1.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ====================================================================================================
#
#
#
#
#
#
#
#
# TESTING PORTFOLIO:  p4
# Best alpha:  0.04768611697714469
# Train set score: 0.95
# Test set score: 0.96
# MSE: 1.91
# Using GridSearchCV, we retain the following Xs out of 31 Xs
# ('exmt', 4.689) ('share_issue_delta', -0.002) ('shortterm_rev_delta', -0.248) ('longterm_rev_delta', 0.0) ('innov_delta', 0.0) ('growth_delta', 0.0) ('durable_delta', -0.06) ('service_minus_goods', 0.0) ('needs_minus_wants', -0.0) ('accrual_delta', -0.0) ('cashflow_price_delta', 0.0) ('market_beta_delta', 0.0) ('dividend_yield_delta', -0.0) ('earnings_price_delta', 0.0) ('variance_delta', 0.629) ('AgricMinusSteel', -0.0) ('AgricMinusChips', 0.0) ('SodaMinusTxtls', 0.0) ('HshldMinusClths', 0.002) ('HshldMinusTxtls', -0.018) ('HshldMinusAero', 0.0) ('HshldMinusBoxes', -0.042) ('HshldMinusBanks', -0.0) ('MedEqMinusChips', 0.192) ('DrugsMinusHardw', -0.0) ('DrugsMinusBanks', 0.0) ('SMB', -2.312) ('HML', 0.045) ('RMW', -0.121) ('CMA', 0.0) ('MOM', 1.72)
# RETAINED Xs:
#  0                    exmt
# 1       share_issue_delta
# 2     shortterm_rev_delta
# 6           durable_delta
# 14         variance_delta
# 18        HshldMinusClths
# 19        HshldMinusTxtls
# 21        HshldMinusBoxes
# 23        MedEqMinusChips
# 26                    SMB
# 27                    HML
# 28                    RMW
# 30                    MOM
# dtype: object
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     p4   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1174.
# Date:                Wed, 12 Apr 2023   Prob (F-statistic):               0.00
# Time:                        18:58:12   Log-Likelihood:                -1193.1
# No. Observations:                 711   AIC:                             2414.
# Df Residuals:                     697   BIC:                             2478.
# Df Model:                          13
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.6190      0.053     11.772      0.000       0.516       0.722
# exmt                  105.5824      1.500     70.390      0.000     102.637     108.527
# share_issue_delta      -0.0259      0.020     -1.278      0.202      -0.066       0.014
# shortterm_rev_delta    -0.0503      0.010     -4.932      0.000      -0.070      -0.030
# durable_delta          -0.0228      0.012     -1.827      0.068      -0.047       0.002
# variance_delta          0.0869      0.012      6.992      0.000       0.062       0.111
# HshldMinusClths         0.1290      0.064      2.017      0.044       0.003       0.255
# HshldMinusTxtls        -0.1059      0.070     -1.510      0.131      -0.244       0.032
# HshldMinusBoxes        -0.0998      0.056     -1.773      0.077      -0.210       0.011
# MedEqMinusChips         0.1614      0.057      2.833      0.005       0.050       0.273
# SMB                    -0.4903      0.016    -31.086      0.000      -0.521      -0.459
# HML                     0.0094      0.013      0.728      0.467      -0.016       0.035
# RMW                    -0.0450      0.017     -2.594      0.010      -0.079      -0.011
# MOM                     0.2587      0.008     31.806      0.000       0.243       0.275
# ==============================================================================
# Omnibus:                       21.719   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.606
# Skew:                           0.224   Prob(JB):                     1.12e-08
# Kurtosis:                       4.018   Cond. No.                         312.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ====================================================================================================
